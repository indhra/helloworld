# %% [markdown]
# # Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # Numpy
# * ![image.png](attachment:0b1e0bb7-0b75-4678-a365-638e257af1aa.png)
# * a
# * ![image.png](attachment:71dac8c8-3343-4b26-b373-5ff7a78a0d6b.png)
# * Another
# * ![image.png](attachment:6a8390ae-0cf6-4e5d-a74c-49b60e7ff8db.png)
# * ravel refers to the original array and does not make a copy of it, hence it faster compared to flatten - this makes a copy of it and changing this will not change the original
# * reshape does not change the original array and creates a new array and for missing values it will throw an erro
# * resize it changes the array inplace and its faster, it also fills the missing values with zeros-0

# %%
data_numpy = pd.read_csv('/kaggle/input/heart-disease-dataset/heart_statlog_cleveland_hungary_final.csv')
data_numpy.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
np.genfromtxt('/kaggle/input/heart-disease-dataset/heart_statlog_cleveland_hungary_final.csv',delimiter=',')
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [40. ,  1. ,  2. , ...,  0. ,  1. ,  0. ],
#        [49. ,  0. ,  3. , ...,  1. ,  2. ,  1. ],
#        ...,
#        [57. ,  1. ,  4. , ...,  1.2,  2. ,  1. ],
#        [57. ,  0. ,  2. , ...,  0. ,  2. ,  1. ],
#        [38. ,  1. ,  3. , ...,  0. ,  1. ,  0. ]])

# %% [markdown]
# # Pandas
# * ![image.png](attachment:173f1054-ceab-42c0-9b1b-250c31f3ab3e.png)
# * ![image.png](attachment:4cfca33f-4cde-4464-bf67-c203b1e2e972.png)

# %% [markdown]
# # Scikit-learn
# * ![image.png](attachment:4691c3c9-dbb5-4d17-8014-f4ae30bd8260.png)
# * ![image.png](attachment:cb0eb4b8-539e-4a48-8f9d-0ebc79773334.png)
# * ![image.png](attachment:e107c4a1-3adb-4c89-b670-b87c29ec2fcc.png)
# * ![image.png](attachment:f7a62f9b-3218-47e9-9a6c-3653c8efb7f6.png)
# * ![image.png](attachment:acfcbc6f-4d80-4652-b224-76221797ba9a.png)
# * ![image.png](attachment:8926cd58-f80c-402e-96ba-64a221932f3d.png)
# * ![image.png](attachment:5267cb9c-2e3b-474e-ad5c-24f773fe6e78.png)

# %% [markdown]
# # Stats Models

# %% [markdown]
# # Matplotlib

# %% [markdown]
# # End
